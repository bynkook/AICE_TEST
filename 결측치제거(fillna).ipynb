# %%
import pandas as pd
import numpy as np

df = pd.DataFrame([
    [1,2,3],
    [4,None,6],
    [7,8,None]],
    columns=list('ABC')
)

df
# Out:
#    A    B    C
# 0  1  2.0  3.0
# 1  4  NaN  6.0
# 2  7  8.0  NaN

# %%
df_1 = df.fillna({'C':100})
df_1
# Out:
#    A    B      C
# 0  1  2.0    3.0
# 1  4  NaN    6.0
# 2  7  8.0  100.0

# %%
df['C'] = df['C'].fillna(100)
df_2 = df.copy()
df_2
# Out:
#    A    B      C
# 0  1  2.0    3.0
# 1  4  NaN    6.0
# 2  7  8.0  100.0

# %%
# 이렇게 하면 바보됨.
df = df['C'].fillna(100)
df_3 = df.copy()
df_3
# Out:
# 0      3.0
# 1      6.0
# 2    100.0
# Name: C, dtype: float64
